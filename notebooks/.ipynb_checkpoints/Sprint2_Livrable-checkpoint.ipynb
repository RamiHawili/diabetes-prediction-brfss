# %% [markdown]
# # Sprint 2 : Construction d’un réseau de neurones
# ### Projet : Prédiction du risque de diabète - BRFSS 2015
# ---
# **Formation** : FISE A4 Data & IA - CESI Bordeaux
# **Dataset** : `diabetes_012_health_indicators_BRFSS2015.csv`
# **Livrable** : Sprint 2 : Modèles de prédiction et leurs évaluations

# %% [markdown]
# ## Sommaire
#
# 1. Contexte
# 2. Objectif
# 3. Contraintes
# 4. Imports et configuration
# 5. Chargement des datasets
# 6. Justification des choix d'architecture
# 7. Construction des modèles
#  7.1 Construction, entraînement et évaluation du Modèle A
#  7.2 Construction, entraînement et évaluation du Modèle B
# 9. Comparaison des modèles A et B
# 10. Amélioration du modèle retenu
# 11. Analyse du seuil de décision
# 12. Comparaison finale
# 13. Conclusion
# 14. Bibliographie

# %% [markdown]
# ## 1. Contexte
#
# &nbsp;&nbsp;&nbsp;&nbsp;Aux États-Unis, le diabète est l'une des maladies chroniques les plus répandues. En 2018, les CDC (les Centres pour le contrôle et la prévention des maladies) estimaient à 34,2 millions le nombre d'Américains diabétiques, et à 88 millions ceux en état de prédiabète; dont une grande majorité ignorait leur situation.
#
# Cette maladie cause un dérèglement du sucre sanguin, ce qui, sur le long terme, peut engendrer des complications graves : maladies cardiovasculaires, insuffisance rénale, amputations, perte de la vue. Son coût économique est estimé à près de 400 milliards de dollars par an.
#
# Le dataset utilisé provient du *Behavioral Risk Factor Surveillance System (BRFSS)*, une enquête téléphonique annuelle menée par les CDC auprès de plus de 400 000 Américains. Notre version (2015) contient 253 680 réponses et 22 variables relatives aux comportements de santé, antécédents médicaux et conditions socio-économiques des participants.
#
#
# &nbsp;&nbsp;&nbsp;&nbsp;Le **livrable 2** constitue la partie "Construction, entraînement et évaluation de réseaux de neurones" du projet.
# C'est dans ce dernier que nous allons construire des modèles de plus en plus complexes dans le but de les comparer et ainsi de réussir à la fois à prédire le diabète avec le plus de précision possible, mais aussi à comprendre et déterminer les paramètres les plus impactants.
# Cela nous permettra enfin d'analyser les limites et axes d'amélioration de notre "meilleur modèle" pour tenter de l'optimiser dans le livrable 3.
#
# L'échéance de ce livrable est fixée au 28 mai 2026 à minuit.

# %% [markdown]
# ## 2. Objectifs
#
# L'objectif de ce livrable est double.
#
# D'abord, il doit nous permettre d'apprendre à construire notre premier réseau de neurones, c'est-à-dire de comprendre comment les étapes de construction, d'entraînement et d'évaluation se définissent et s'enchaînent (exécution séquentielle).
#
# Ensuite, il doit nous permettre de découvrir d'autres types de paramètres propres au Deep Learning qui permettent d'améliorer les performances globales d'un modèle (le rendre plus complexe et profond).
#
# Le but est de prendre le modèle le plus performant, d'essayer de l'améliorer en variant différents paramètres et pourquoi pas en ajoutant de la complexité si utile et non contre-productive (hypothèse), mais aussi de produire un modèle capable de fonctionner correctement sur de nouvelles données de patients qu'il n'a jamais vues.

# %% [markdown]
# ## 3. Contraintes
#
# Les contraintes de ce livrable sont multiples :
#
# - Elles sont **médicales**. Si le modèle ne détecte pas un diabète chez un patient (un faux négatif), c'est bien plus grave que de signaler un diabète chez un patient qui n'en a pas en réalité. Une consultation approfondie "pour rien au final" est moins grave qu'un patient qui malheureusement décède parce que son diabète n'a pas été détecté à temps.
#
# - Elles sont **éthiques**. Le modèle est amené à être utilisé par des médecins. Des vies humaines sont en jeu et ce dernier a un impact direct sur l'avenir des patients.
#
# - Le modèle doit trouver le juste milieu entre performance et explicabilité. Puisque des médecins sont amenés à l'utiliser, ils doivent pouvoir en interpréter les résultats. Si le modèle est trop complexe, il est peu voire pas du tout explicable et n'est donc pas utilisable en conditions réelles.
#
# - Le modèle doit être capable de généraliser, c'est-à-dire qu'il doit éviter le **surapprentissage** pour être capable de fonctionner correctement sur de nouvelles données qu'il n'a jamais vues.
# Un modèle en surapprentissage mémorise les données d'entraînement au lieu d'en apprendre les patterns généraux, alors il performe très bien à l'entraînement mais devient inefficace face à de nouvelles données.
#
# - Le jeu de données présente un **déséquilibre des classes** important (86% de non-diabétiques contre 14% de diabétiques). Ce déséquilibre a été partiellement traité dans le livrable 1 via SMOTE sur le jeu d'entraînement, mais les jeux de validation et de test conservent la distribution réelle.
# L'accuracy seule ne suffit donc pas comme métrique d'évaluation.

# %% [markdown]
# ## 4. Imports et configuration

# %%
# Suppression des avertissements non critiques
import warnings
warnings.filterwarnings('ignore')

# Librairies de base
import numpy as np
import pandas as pd
import time
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # 0=tout, 1=info, 2=warning, 3=error seulement

DATA_PATH = 'data/processed/'

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# TensorFlow / Keras
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#import keras_tuner as kt

# Métriques d'évaluation
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    ConfusionMatrixDisplay
)

# Configuration graphique
sns.set_theme(style='whitegrid', palette='muted', font_scale=1.1)
plt.rcParams['figure.figsize'] = (10, 5)

# Graine aléatoire pour la reproductibilité des résultats
RANDOM_STATE = 42
tf.random.set_seed(RANDOM_STATE)
np.random.seed(RANDOM_STATE)

print('TensorFlow version :', tf.__version__)
print('Imports OK')
# Out:
# TensorFlow version : 2.21.0
# Imports OK

# %% [markdown]
# ## 5. Chargement des datasets

# %%
# Features
X_train = pd.read_csv(os.path.join(DATA_PATH, 'X_train.csv'))
X_val   = pd.read_csv(os.path.join(DATA_PATH, 'X_val.csv'))
X_test  = pd.read_csv(os.path.join(DATA_PATH, 'X_test.csv'))

# Labels
y_train = pd.read_csv(os.path.join(DATA_PATH, 'y_train.csv'))
y_val   = pd.read_csv(os.path.join(DATA_PATH, 'y_val.csv'))
y_test  = pd.read_csv(os.path.join(DATA_PATH, 'y_test.csv'))

# Aperçu des dimensions
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (305668, 18)
# (38052, 18)
# (38052, 18)
# (305668, 1)
# (38052, 1)
# (38052, 1)

# %% [markdown]
# ## 6. Justification des choix d'architecture

# %% [markdown]
# ### Analyse du problème
# Avant de construire le réseau, il faut identifier les caractéristiques du problème qui comptent le plus.
# La tâche à réaliser est une classification binaire, c'est-à-dire que la sortie est un seul neurone avec une fonction d'activation que l'on choisira plus tard dans ce livrable pour construire les modèles.
#
#
# ### Non-linéarité des données
# Lors de l'analyse exploratoire du Sprint 1, nous avons relevé que les variables n'ont pas de relation linéaire avec la variable cible, c'est-à-dire que les variables n'évoluent pas les unes en fonction des autres de façon ordonnée. Il faut donc exclure l'idée de créer un modèle de prédiction linéaire.
#
#
# ### Déséquilibre des classes
# L'analyse du Sprint 1 a aussi montrer que la repartition dans le dataset est d'environ 86% de non-diabétiques et 14% de diabétiques.
#
# Pour évaluer nos modèles, on ne peut pas se contenter de l'accuracy. L'accuracy mesure le pourcentage de bonnes prédictions. Le problème c'est que même si on a rééquilibré le jeu d'entraînement avec **SMOTE**, le jeu de validation et de test gardent leur distribution réelle : environ 86% de non-diabétiques contre 14% de diabétiques. Un modèle qui prédirait toujours "non diabétique" aurait donc 86% d'accuracy sans avoir rien appris.
#
# C'est pourquoi on utilise la **ROC-AUC** comme métrique principale. La ROC-AUC mesure la capacité du modèle à distinguer les diabétiques des non-diabétiques, quelle que soit la distribution des classes. Une valeur de 1 signifie que le modèle sépare parfaitement les deux classes, une valeur de 0.5 équivaut à une prédiction aléatoire. Elle est donc bien plus fiable que l'accuracy dans notre cas.
#
# On observe aussi le **recall**, dans un contexte médical, rater un diabétique est plus grave que signaler un faux positif. Un faux positif mènera à des analyses supplémentaires, ce qui est acceptable. Un faux négatif, lui, laisse un patient diabétique sans prise en charge.
#
# ### Contrainte médicale, l'importance des faux négatifs
# Un des graphes d'analyse les plus importants est la matrice de confusion à 4 cases :
# - **TN** (Vrai Négatif) : sont les non-diabétiques bien classés
# - **FP** (Faux Positif) : sont les non-diabétiques classés diabétiques. Le patient fera des analyses supplémentaires, ce qui est acceptable
# - **FN** (Faux Négatif) : sont les diabétiques non détectés, c'est le cas le plus dangereux car le patient ne sera pas pris en charge
# - **TP** (Vrai Positif) : sont les diabétiques bien détectés, c'est ce qu'on cherche à maximiser
#
# L'objectif de cette matrice est de minimiser les FN et donc de maximiser le recall.
#
# ### Équilibre entre performance et explicabilité
# Plus le réseau de neurone est profond (plusieurs couche de fonctions) et plus il est difficile d'expliquer ses décisions. On cherche alors a realiser un modèle efficace mais pas inutilement complexe.
#
# ### Les deux architectures
#
# Nous allons dans ce livrable réaliser deux modèles. Un modèle A très simple dont on observera les performances, et ensuite un modèle B plus complexe dont nous comparerons les performances au modèle A.
#
# **Modèle A : Simple**
# Il sera constitué de une couche cachée, c'est la couche intermédiaire entre l'entrée et la sortie, là où le réseau apprend à détecter des patterns dans les données.
# L'objectif est de créer un premier modèle de prédiction fonctionnel pour comprendre les mécanismes de base avant de passer à une architecture intermédiaire.
#
# **Modèle B : Intermédiaire**
# Il sera constitué de deux couches cachées, c'est la couche intermédiaire entre l'entrée et la sortie, là où le réseau apprend à détecter des patterns dans les données.
# L'objectif est de créer un second modèle de prédiction un peu plus complexe et l'analyser avant de passer à une architecture plus prodonde.
#
# **Modèle C : Plus profond**
# Il sera constitué de trois couches cachées.

# %% [markdown]
# ## 7. Construction des modèles

# %%
input_dim = X_train.shape[1]  # nombre de features en entrée : 18

# %%
def build_model_A(input_dim):
    model = Sequential([
        Input(shape=(input_dim,)),
        Dense(8, activation = 'relu', kernel_regularizer = l2(1e-4)),   # 2ème couche cachée : 8 neurones
        Dense(1, activation = 'sigmoid')                              # sortie : probabilité entre 0 et 1
    ], name="model_A")
    
    model.compile(
        optimizer = Adam(learning_rate = 1e-3),
        loss = 'binary_crossentropy',
        metrics = ['accuracy']
    )
    return model

model_A = build_model_A(input_dim)
model_A.summary()

# %%
early_stop = EarlyStopping(
    monitor = 'val_loss',        # surveille la loss sur la validation
    patience = 10,               # attend 10 epochs sans amélioration avant de stopper
    restore_best_weights = True  # remet les poids du meilleur epoch
)

EPOCHS     = 50  # nombre maximum d'epochs
BATCH_SIZE = 64   # nombre de lignes traitées par paquet
# Seuil de décision : si probabilité >= 0.5 → diabétique, sinon → non diabétique
THRESHOLD = 0.5

# %% [markdown]
# #### 7.1.3 Entraînement du Modèle A
#
# Maintenant on lance l'entraînement. Le modèle va apprendre sur X_train et on surveille ses performances sur X_val à chaque epoch grâce à l'EarlyStopping.

# %% [markdown]
# ---
# ### 7.1 Modèle A : Simple
#
# Le Modèle A est notre architecture de référence. Il est volontairement simple, c'est à dire deux couches cachées avec peu de neurones.
#
# En entrée, le réseau reçoit les 18 variables de santé de chaque patient.
# Ces informations traversent d'abord une première couche de 16 neurones, puis une deuxième de 8 neurones, où le réseau va progressivement apprendre à combiner les variables entre elles pour mieux prédire le risque de diabète.
# En sortie, un seul neurone produit une probabilité entre 0 et 1 et plus elle est proche de 1, plus le patient a de risques d'être diabétique.
#
# #### 7.1.1 Les fonctions d'activation
#
# Les fonctions d'activation sont des fonctions mathématiques appliquées à la sortie de chaque neurone. Sans elles, le réseau ne serait qu'une succession de calculs linéaires et ne pourrait pas apprendre des relations complexes entre les variables.
#
# - Le **ReLU** (Rectified Linear Unit) est la fonction la plus utilisée pour les couches cachées.
# Son principe est simple, si la valeur est négative elle renvoie 0, sinon elle renvoie la valeur telle quelle.
# On l'utilise car elle permet au réseau d'ignorer les signaux non pertinents (en renvoyant 0) et de laisser passer uniquement les informations utiles, ce qui aide le modèle à mieux apprendre les relations entre les variables.
#
# - Le **Sigmoid** est la fonction que l'on utilise uniquement sur la couche de sortie.
# Elle transforme n'importe quelle valeur en un nombre entre 0 et 1, ce qui correspond exactement à une probabilité.
# C'est donc le meilleur choix pour notre classification binaire puisque ainsi, le réseau nous dit "cette personne a X% de chances d'être diabétique".

# %%
def build_model_A(input_dim):
    model = Sequential([
        Input(shape=(input_dim,)),
        Dense(16, activation='relu', kernel_regularizer=l2(1e-4)),  # 1ère couche cachée : 16 neurones
        Dense(8, activation='relu', kernel_regularizer=l2(1e-4)),   # 2ème couche cachée : 8 neurones
        Dense(1, activation='sigmoid')                               # sortie : probabilité entre 0 et 1
    ], name="model_A")
    
    model.compile(
        optimizer=Adam(learning_rate=1e-3),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

model_A = build_model_A(input_dim)
model_A.summary()
# Out:
# Model: "model_A"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 16)                  │             304 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 449 (1.75 KB)
#  Trainable params: 449 (1.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### 7.1.2 Rappel des mots-clés
#
# Une couche **Dense** est une couche où chaque neurone est connecté à tous les neurones de la couche précédente. Par exemple Dense(8, relu) signifie une couche de 8 neurones avec la fonction d'activation ReLU.
#
# L'optimizer **Adam** est l'algorithme qui ajuste les poids du modèle après chaque erreur. On l'utilise car il adapte automatiquement la vitesse d'apprentissage pour chaque paramètre, ce qui le rend plus efficace que des algorithmes plus basiques sur des datasets de grande taille comme le nôtre.
#
# La loss **binary_crossentropy** mesure l'écart entre la probabilité prédite par le modèle et la vraie classe (0 ou 1). On l'utilise car elle est mathématiquement adaptée aux problèmes où la sortie est une probabilité entre 0 et 1.
#
# Le **kernel_regularizer = l2(1e-4)** pénalise les poids trop élevés pendant l'entraînement pour éviter que le modèle ne s'adapte trop aux données d'entraînement au détriment de la généralisation.
#
# Le **biais** est un paramètre supplémentaire ajouté automatiquement par Keras à chaque couche Dense. il permet au modèle de décaler sa sortie indépendamment des entrées.
# Sans lui, le réseau perdrait une grande partie de sa flexibilité car si toutes les entrées d'un neurone valaient 0, sa sortie serait forcément 0 quels que soient ses poids.
# Le biais lui permet de produire une sortie non nulle dans ce cas, ce qui lui donne plus de liberté pour s'adapter aux données.
#
# La **patience** de l'EarlyStopping définit le nombre d'epochs consécutives sans amélioration de la loss de validation au-delà duquel l'entraînement s'arrête automatiquement.
#
# Le choix de **16 puis 8 puis 1 neurones** suit une logique de compression progressive de l'information, inspirée des puissances de 2.
# À chaque couche, le réseau est forcé de résumer ce qu'il a appris avec moins de neurones, comme un entonnoir qui garde uniquement les informations utiles pour la prédiction finale.

# %% [markdown]
# ### Configuration de l'entraînement
#
# Avant de lancer l'entraînement, on définit deux éléments importants : l'EarlyStopping et les hyperparamètres de base. Chaque modèle dispose de son propre EarlyStopping afin de pouvoir faire varier ses paramètres indépendamment.
#
# Le **EarlyStopping** surveille la loss sur la validation à chaque epoch. Si elle ne s'améliore pas pendant 10 epochs de suite, l'entraînement s'arrête automatiquement et les meilleurs poids sont restaurés.
# Cela évite que le modèle apprenne trop bien les données d'entraînement au point de ne plus généraliser.
#
# **Les hyperparamètres de base :**
#
# - L'**EPOCHS** est fixé à 100, c'est le nombre maximum de fois que le modèle va parcourir toutes les données d'entraînement. En pratique EarlyStopping s'arrêtera bien avant.
#
# - Le **BATCH_SIZE** est fixé à 64, ce qui signifie qu'au lieu de traiter toutes les données d'un coup, le modèle les traite par paquets de 64 lignes. Après chaque paquet il ajuste ses poids.

# %% [markdown]
# #### 7.1.3 Entraînement du Modèle A
#
# Maintenant on lance l'entraînement. Le modèle va apprendre sur X_train et on surveille ses performances sur X_val à chaque epoch grâce à l'EarlyStopping.

# %%
history_A = model_A.fit(
    X_train, y_train,
    validation_data = (X_val, y_val),  # surveillance sur la validation
    epochs = EPOCHS,
    batch_size = BATCH_SIZE,           
    callbacks = [early_stop_A],          # active l'EarlyStopping à chaque fin d'epoch
    verbose = 1                        # affiche la loss et l'accuracy à chaque epoch
)
# Out:
# Epoch 1/50
# 4777/4777 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.7407 - loss: 0.5215 - val_accuracy: 0.6832 - val_loss: 0.5574
# Epoch 2/50
# 4777/4777 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.7468 - loss: 0.5118 - val_accuracy: 0.6841 - val_loss: 0.5575
# Epoch 3/50
# 4777/4777 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.7478 - loss: 0.5103 - val_accuracy: 0.6849 - val_loss: 0.5553
# Epoch 4/50
# 4777/4777 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.7482 - loss: 0.5095 - val_accuracy: 0.6880 - val_loss: 0.5529
# Epoch 5/50
# 4777/4777 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.7485 - loss: 0.5088 - val_accuracy: 0.6899 - val_loss: 0.5521
# Epoch 6/50
# 4777/4777 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.7488 - loss: 0.5082 - val_accuracy: 0.6898 - val_loss: 0.5533
# Epoch 7/50
# 4777/4777 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.7491 - loss: 0.5077 - val_accuracy: 0.6886 - val_loss: 0.5527
# Epoch 8/50
# ...

# %% [markdown]
# #### 7.1.4 Évaluation sur la validation
#
# On évalue le Modèle A sur le jeu de validation avec un seuil de 0.5 par défaut.

# %%
# Prédictions : le modèle renvoie des probabilités entre 0 et 1
y_prob_A = model_A.predict(X_val, verbose=0).ravel()

y_pred_A = (y_prob_A >= THRESHOLD).astype(int)

# Calcul des métriques d'évaluation
acc_A  = accuracy_score(y_val,  y_pred_A)
prec_A = precision_score(y_val, y_pred_A, zero_division=0)
rec_A  = recall_score(y_val,    y_pred_A, zero_division=0)  # priorité : minimiser les FN
f1_A   = f1_score(y_val,        y_pred_A, zero_division=0)
auc_A  = roc_auc_score(y_val,   y_prob_A)  # métrique principale : insensible au déséquilibre des classes

# Décomposition de la matrice de confusion en 4 valeurs
cm_A = confusion_matrix(y_val, y_pred_A)
tn_A, fp_A, fn_A, tp_A = cm_A.ravel()

print(f'Résultats Modèle A : Validation (seuil = {THRESHOLD})')
print(f'  Accuracy  : {acc_A:.4f}')
print(f'  Precision : {prec_A:.4f}')
print(f'  Recall    : {rec_A:.4f}')
print(f'  F1-score  : {f1_A:.4f}')
print(f'  ROC-AUC   : {auc_A:.4f}')
print(f'\n  TN={tn_A}  FP={fp_A}')
print(f'  FN={fn_A}  TP={tp_A}')
print(f'\n  Résultat : {fn_A} diabétiques non détectés')  # FN : cas les plus dangereux
# Out:
# Résultats Modèle A : Validation (seuil = 0.5)
#   Accuracy  : 0.6899
#   Precision : 0.2776
#   Recall    : 0.7652
#   F1-score  : 0.4075
#   ROC-AUC   : 0.7919
#
#   TN=22195  FP=10555
#   FN=1245  TP=4057
#
#   Résultat : 1245 diabétiques non détectés

# %%
fig, ax = plt.subplots(figsize=(6, 5))
disp = ConfusionMatrixDisplay(confusion_matrix=cm_A,
                               display_labels=['Non diabétique', 'Diabétique'])
disp.plot(ax=ax, cmap='Blues', values_format='d', colorbar=False)
ax.set_title('Matrice de confusion : Modèle A (seuil = 0.5)')
plt.tight_layout()
plt.show()

# %%
plt.plot(history_A.history['loss'], label='Train')
plt.plot(history_A.history['val_loss'], label='Validation', linestyle='--')
plt.title('Courbes d\'apprentissage : Modèle A')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# #### 7.1.5 Analyse des résultats du Modèle A
#
# Les résultats du Modèle A sont cohérents avec ce qu'on attendait d'une architecture simple.
#
# - Le **ROC-AUC** de 0.79 montre que le modèle arrive quand même à distinguer les diabétiques des non diabétiques dans 79% des cas, ce qui est correct pour un premier modèle simple.
#
# - Le **recall** de 0.76 signifie que le modèle détecte 3 diabétiques sur 4. C'est un début mais dans un contexte médical, chaque cas manqué peut avoir des conséquences graves.
#
# - La **précision** de 0.27 est très faible : sur 10 personnes classées comme diabétiques, seulement 3 le sont vraiment. Cela donne 10 663 faux positifs, ce qui est énorme.
#
# - Le point le plus critique est le FN = 1277. Ce sont 1277 diabétiques que le modèle n'a pas détectés. Ne pas détecter une maladie est bien plus grave que de faire passer un non-malade en consultation supplémentaire.
#
# Sur le plan éthique et légal, un modèle utilisé en milieu médical est soumis à plusieurs réglementations importantes:
# - Les données de santé sont des données sensibles selon l'**article 9 du RGPD**, ce qui impose des règles sur leur collecte et leur traitement.
# - En France, la **CNIL** veille au respect de ces règles pour les traitements automatisés de données médicales.
# - Depuis août 2024, le **règlement européen sur l'IA (AI Act, Annexe III point 5)** classe plusieurs systèmes médicaux comme systèmes à "haut risque", ce qui impose des exigences de transparence et de contrôle humain. Notre modèle s'inscrit dans cet esprit : le médecin reste seul responsable du diagnostic final, le modèle ne peut être qu'un outil d'aide à la décision.
#
# Avec seulement **449 paramètres** sur 2 couches cachées, le Modèle A est une architecture très légère. Il s'est arrêté à **19 epochs** grâce à l'EarlyStopping, ce qui montre qu'il converge rapidement mais atteint vite ses limites.
#
# Les courbes d'apprentissage confirment un surapprentissage. La loss d'entraînement descend régulièrement alors que la loss de validation reste stable voire remonte légèrement. Le modèle apprend bien sur les données d'entraînement mais ne généralise pas correctement sur de nouvelles données.

# %% [markdown]
# ---
# ### 7.2 Modèle B : Plus profond
#
# Le Modèle B est notre architecture avancée. Par rapport au Modèle A, on ajoute une couche cachée supplémentaire et un mécanisme pour éviter que le modèle n'apprenne trop bien les données d'entraînement au point de ne plus fonctionner sur de nouvelles données.
#
# En entrée, le réseau reçoit les 18 variables de santé de chaque patient.
# Ces informations traversent une première couche de 32 neurones, puis une deuxième de 16 neurones, puis une troisième de 8 neurones. À chaque couche, le réseau apprend à combiner les variables entre elles pour mieux détecter le risque de diabète.
# En sortie, un seul neurone produit une probabilité entre 0 et 1.
#
# #### 7.2.1 Le Dropout
#
# Le **Dropout** est une technique en Deep Learning pour éviter l'overfitting. L'**overfitting** c'est quand le modèle apprend trop bien les données d'entraînement.
# Il mémorise les exemples au lieu de comprendre les patterns généraux, et du coup il devient mauvais sur de nouvelles données qu'il n'a jamais vues.
# À chaque étape d'entraînement, on désactive aléatoirement un certain pourcentage de neurones, comme si on les "éteignait" temporairement.
#
# On utilise ici un taux de 0.4, ce qui veut dire que 40% des neurones sont ignorés à chaque passage.
# Ce taux a été choisi car il représente un bon compromis entre un pourcentage trop faible par exemple 0.1 qui n'apporterait pas grand chose et un pourcentage trop élevé par exemple 0.5 qui perturberait trop l'apprentissage.
#
# En resumé, cela force le réseau à ne pas trop compter sur un seul neurone et à apprendre de façon plus robuste et généralisable.

# %%
def build_model_B(input_dim):
    model = Sequential([
        Input(shape = (input_dim,)),
        Dense(32, activation = 'relu', kernel_regularizer = l2(1e-4)),  # 1ère couche cachée : 32 neurones
        Dropout(0.4),                                                # régularisation : désactive 40% des neurones
        Dense(16, activation = 'relu', kernel_regularizer = l2(1e-4)), # 2ème couche cachée : 16 neurones
        Dropout(0.4),                                                # régularisation : désactive 40% des neurones
        Dense(8, activation = 'relu', kernel_regularizer = l2(1e-4)),  # 3ème couche cachée : 8 neurones
        Dense(1, activation = 'sigmoid')                              # sortie : probabilité entre 0 et 1
    ], name="model_B")
    
    model.compile(
        optimizer = Adam(learning_rate=5e-4),
        loss = 'binary_crossentropy',
        metrics = ['accuracy']
    )
    return model

model_B = build_model_B(input_dim)
model_B.summary()
# Out:
# Model: "model_B"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 32)                  │             608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 16)                  │               0 │
# ...

# %%
early_stop_B = EarlyStopping(
    monitor = 'val_loss',        # surveille la loss sur la validation
    patience = 15,               # attend 15 epochs sans amélioration avant de stopper
    restore_best_weights = True  # remet les poids du meilleur epoch
)
# Seuil de décision : si probabilité >= 0.5 → diabétique, sinon → non diabétique
THRESHOLD = 0.5

# %% [markdown]
# #### 7.2.2 Entraînement du Modèle B
#
# Maintenant on lance l'entraînement du Modèle B. Comme pour le Modèle A, il va apprendre sur X_train et on surveille ses performances sur X_val à chaque epoch grâce à l'EarlyStopping.

# %%
history_B = model_B.fit(
    X_train, y_train,
    validation_data = (X_val, y_val),  # surveillance sur la validation
    epochs = EPOCHS,
    batch_size = BATCH_SIZE,
    callbacks = [early_stop_B],          # active l'EarlyStopping à chaque fin d'epoch
    verbose = 1                        # affiche la loss et l'accuracy à chaque epoch
)
# Out:
# Epoch 1/50
# 4777/4777 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.7181 - loss: 0.5612 - val_accuracy: 0.6863 - val_loss: 0.5174
# Epoch 2/50
# 4777/4777 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.7406 - loss: 0.5325 - val_accuracy: 0.7008 - val_loss: 0.5288
# Epoch 3/50
# 4777/4777 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.7431 - loss: 0.5267 - val_accuracy: 0.6949 - val_loss: 0.5479
# Epoch 4/50
# 4777/4777 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.7438 - loss: 0.5243 - val_accuracy: 0.6916 - val_loss: 0.5510
# Epoch 5/50
# 4777/4777 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.7437 - loss: 0.5228 - val_accuracy: 0.6923 - val_loss: 0.5451
# Epoch 6/50
# 4777/4777 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.7440 - loss: 0.5215 - val_accuracy: 0.6917 - val_loss: 0.5551
# Epoch 7/50
# 4777/4777 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.7449 - loss: 0.5203 - val_accuracy: 0.6914 - val_loss: 0.5496
# Epoch 8/50
# ...

# %% [markdown]
# #### 7.2.3 Évaluation sur la validation
#
# On évalue le Modèle B sur le jeu de validation avec un seuil de 0.5 par défaut.

# %%
# Prédictions : le modèle renvoie des probabilités entre 0 et 1
y_prob_B = model_B.predict(X_val, verbose=0).ravel()

# Seuil de décision : si probabilité >= 0.5 → diabétique, sinon → non diabétique
y_pred_B = (y_prob_B >= THRESHOLD).astype(int)

# Calcul des métriques d'évaluation
acc_B  = accuracy_score(y_val,  y_pred_B)
prec_B = precision_score(y_val, y_pred_B, zero_division=0)
rec_B  = recall_score(y_val,    y_pred_B, zero_division=0)  # priorité : minimiser les FN
f1_B   = f1_score(y_val,        y_pred_B, zero_division=0)
auc_B  = roc_auc_score(y_val,   y_prob_B)  # métrique principale : insensible au déséquilibre des classes

# Décomposition de la matrice de confusion en 4 valeurs
cm_B = confusion_matrix(y_val, y_pred_B)
tn_B, fp_B, fn_B, tp_B = cm_B.ravel()

print(f'Résultats Modèle B : Validation (seuil = {THRESHOLD})')
print(f'  Accuracy  : {acc_B:.4f}')
print(f'  Precision : {prec_B:.4f}')
print(f'  Recall    : {rec_B:.4f}')
print(f'  F1-score  : {f1_B:.4f}')
print(f'  ROC-AUC   : {auc_B:.4f}')
print(f'\n  TN={tn_B}  FP={fp_B}')
print(f'  FN={fn_B}  TP={tp_B}')
print(f'\n  Résultat : {fn_B} diabétiques non détectés')  # FN : cas les plus dangereux
# Out:
# Résultats Modèle B : Validation (seuil = 0.5)
#   Accuracy  : 0.6863
#   Precision : 0.2759
#   Recall    : 0.7703
#   F1-score  : 0.4063
#   ROC-AUC   : 0.7928
#
#   TN=22031  FP=10719
#   FN=1218  TP=4084
#
#   Résultat : 1218 diabétiques non détectés

# %%
fig, ax = plt.subplots(figsize=(6, 5))
disp = ConfusionMatrixDisplay(confusion_matrix=cm_B,
                              display_labels=['Non diabétique', 'Diabétique'])
disp.plot(ax=ax, cmap='Blues', values_format='d', colorbar=False)
ax.set_title(f'Matrice de confusion : Modèle B (seuil = {THRESHOLD})')
plt.tight_layout()
plt.show()

# %%
plt.plot(history_B.history['loss'], label='Train')
plt.plot(history_B.history['val_loss'], label='Validation', linestyle='--')
plt.title('Courbes d\'apprentissage : Modèle B')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# #### 7.2.4 Analyse des résultats du Modèle B
#
# Pour ce modèle, on a fait le choix de lui dédier un EarlyStopping propre avec une patience de 15 epochs au lieu de 10 pour le Modèle A, pour lui laisser plus de temps pour apprendre avant de s'arrêter.
#
# - Le **ROC-AUC** de 0.79 montre que le modèle distingue correctement les diabétiques des non diabétiques dans 79% des cas, ce qui est un résultat acceptable pour une classification binaire déséquilibrée.
#
# - Le **recall** de 0.77 signifie que le modèle détecte 3 diabétiques sur 4. C'est encourageant mais dans un contexte médical, chaque cas manqué peut avoir des conséquences graves.
#
# - La **précision** de 0.28 reste faible : sur 10 personnes classées comme diabétiques, seulement 3 le sont vraiment. Cela donne 10 689 faux positifs, ce qui est beaucoup.
#
# - Le point le plus critique reste le FN = 1220. Ce sont 1220 diabétiques que le modèle n'a pas su détecter, c'est la valeur qu'on cherche absolument à faire baisser.
#
# - Dans un contexte médical, ces 1220 patients non détectés représentent un risque. Sans diagnostic, ils ne bénéficient d'aucune prise en charge et s'exposent à des complications qui auraient pu être évitées. C'est la métrique la plus importante à surveiller et à faire baisser.
#
# - Le Modèle A ne compte que **449 paramètres** sur 2 couches cachées, contre **1 281 paramètres** sur 3 couches cachées pour le Modèle B, soit presque 3 fois plus. Malgré cette complexité supplémentaire, le Modèle B s'est arrêté à 16 epochs malgré la patience étendue.
#
# - Les courbes d'apprentissage montrent clairement un surapprentissage. La loss de validation remonte dès l'epoch 1-2 alors que la loss d'entraînement continue de descendre. Le Dropout et la régularisation L2 n'ont pas suffi à corriger ce problème.
#
# Complexifier un modèle ne suffit donc pas à améliorer ses performances.
# Le Modèle B reste globalement au même niveau que le Modèle A, ce qui montre qu'ajouter des couches et de la régularisation ne garantit pas toujours de meilleurs résultats.
#
# D'un point de vue médical et éthique, un modèle qui laisse passer 1220 diabétiques non détectés n'est pas acceptable dans la réalité.
# C'est pourquoi on va d'abord comparer les deux modèles en détail, puis tenter d'optimiser le Modèle B en variant les paramètres existants et en introduisant de nouveaux si possible.

# %% [markdown]
# ## 8. Comparaison des modèles A et B
#
# Maintenant que les deux modèles ont été construits et évalués individuellement, on les compare directement pour décider lequel on va optimiser par la suite.
#
# À noter que les deux modèles n'ont pas exactement les mêmes conditions d'entraînement. Le Modèle B a une patience d'EarlyStopping plus élevée (15 contre 10) et un learning rate plus faible (5e-4 contre 1e-3).
#
# Ces choix sont volontaires : le Modèle B étant plus complexe, on lui a laissé plus de temps pour converger et on a ralenti son apprentissage pour essayer de limiter le surapprentissage qu'on avait observé avec les paramètres par défaut.

# %%
# Tableau comparatif
comparaison = pd.DataFrame([
    {
        'Modèle'                 : 'Modèle A : Simple',
        'Architecture'           : '2 couches cachées (16 puis 8) + Adam lr = 1e-3',
        'Nb paramètres'          : model_A.count_params(),
        'Accuracy'               : round(acc_A, 4),
        'Recall'                 : round(rec_A, 4),
        'F1-score'               : round(f1_A, 4),
        'ROC-AUC'                : round(auc_A, 4),
        'FN (diabétiques ratés)' : int(fn_A)
    },
    {
        'Modèle'                 : 'Modèle B : Plus profond',
        'Architecture'           : '3 couches cachées (32 puis 16 puis 8) + Dropout(0.4) + L2 + Adam lr = 5e-4',
        'Nb paramètres'          : model_B.count_params(),
        'Accuracy'               : round(acc_B, 4),
        'Recall'                 : round(rec_B, 4),
        'F1-score'               : round(f1_B, 4),
        'ROC-AUC'                : round(auc_B, 4),
        'FN (diabétiques ratés)' : int(fn_B)
    }
])

comparaison = comparaison.set_index('Modèle')
print('Comparaison A vs B (sur validation)')
comparaison
# Out:
# Comparaison A vs B (sur validation)
#                                                               Architecture  \
# Modèle
# Modèle A : Simple           2 couches cachées (16 puis 8) + Adam lr = 1e-3
# Modèle B : Plus profond  3 couches cachées (32 puis 16 puis 8) + Dropou...
#
#                          Nb paramètres  Accuracy  Recall  F1-score  ROC-AUC  \
# Modèle
# Modèle A : Simple                  449    0.6899  0.7652    0.4075   0.7919
# Modèle B : Plus profond           1281    0.6863  0.7703    0.4063   0.7928
#
#                          FN (diabétiques ratés)
# Modèle
# Modèle A : Simple                          1245
# Modèle B : Plus profond                    1218

# %%
# Visualisation comparée des courbes de loss
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for ax, history, name in zip(axes,
                              [history_A, history_B],
                              ['Modèle A : Simple', 'Modèle B : Plus profond']):
    ax.plot(history.history['loss'],     label='Train', linewidth=2)
    ax.plot(history.history['val_loss'], label='Validation', linewidth=2, linestyle='--')
    ax.set_title(f'Loss - {name}')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Analyse
#
# En regardant les chiffres, les deux modèles sont très proches sur quasiment toutes les métriques :
#
# - Le ROC-AUC est quasi identique (0.7927 pour A contre 0.7915 pour B) et le recall passe de 0.7682 pour le Modèle A à 0.7765 pour le Modèle B, ce qui reste une amélioration légère.
#
# Ce qui est plus intéressant c'est le nombre de faux négatifs :
#
# - Le Modèle B détecte 44 diabétiques de plus que le Modèle A (1185 FN contre 1229), ce qui dans un contexte médical n'est pas négligeable même si ça reste insuffisant.
#
# En revanche le Modèle B utilise presque 3 fois plus de paramètres (1281 contre 449) pour un gain de performance très faible. Cela confirme ce qu'on avait observé dans les analyses individuelles, ajouter de la complexité ne suffit pas.
#
# Sur les courbes d'apprentissage, les deux modèles présente du surapprentissage :
#
# - Le Modèle A diverge progressivement, sa loss de validation reste stable mais ne descend pas.
# - Le Modèle B diverge plus fortement et plus tôt, sa loss de validation remonte dès l'epoch 1 et devient très instable, ce qui montre que malgré le Dropout et le learning rate réduit, le surapprentissage n'a pas été corrigé.
#
# Malgré ses résultats moyens, c'est le **Modèle B** qu'on choisit d'optimiser. Il est plus complexe et dispose de plus de leviers d'amélioration comme
# le taux de Dropout, le learning rate, le nombre de neurones par couche qui sont des paramètres sur lesquels on peut agir.

# %% [markdown]
# ## 10. Amélioration du modèle retenu
#
# On a vu que le Modèle B fait légèrement mieux que le A, mais il souffre encore d'un surapprentissage (la loss de validation remonte dès l'epoch 4-5) et laisse passer beaucoup de diabétiques non détectés.
#
# L'idée ici c'est de pousser l'architecture plus loin en agissant sur plusieurs paramètres à la fois comme plus de profondeur, un Dropout moins fort, un learning rate plus équilibré et un batch size plus grand.
#
# L'objectif est toujours le même dans ce livrable : améliorer le recall et réduire le surapprentissage.

# %% [markdown]
# ### 10.1 Architecture du Modèle B Amélioré
#
# Par rapport au Modèle B, nous allons faire les changements suivants :
#
# - **4 couches cachées** au lieu de 3 : 64 puis 32 puis 16 puis 8, pour ajouter plus de profondeur pour mieux capturer les relations entre les variables.
#
# - **Dropout à 0.5** au lieu de 0.4 : l'architecture est maintenant plus profonde et plus large (64 neurones en entrée contre 32 pour le Modèle B). Plus le réseau est grand, plus il risque de mémoriser les données d'entraînement. On augmente donc le Dropout pour compenser cette capacité supplémentaire et mieux contrôler le surapprentissage.
# - **Learning rate à 3e-4** : nous allons affiner entre le 1e-3 du Modèle A et le 5e-4 du Modèle B.
# - **Batch size à 128** : sachant que nous avons 250 000 lignes d'entraînement, un batch plus grand stabilise les gradients et accélère l'entraînement.
# - **Patience à 20** : nous allons laisser plus de temps au modèle pour trouver un meilleur minimum avant de s'arrêter.
#
# - **Régularisation L2 à 1e-3** au lieu de 1e-4 : avec un réseau plus profond et plus large, les poids risquent davantage de devenir trop grands. On renforce donc la pénalisation pour mieux contrôler l'overfitting.
#
# - **Epochs à 100** au lieu de 50 : on relève le plafond maximum d'entraînement pour laisser plus de chances au modèle de converger, sachant que l'EarlyStopping s'arrêtera de toute façon avant si nécessaire.

# %%
def build_model_B_improved(input_dim):
    model = Sequential([
        Input(shape = (input_dim,)),
        Dense(64, activation = 'relu', kernel_regularizer = l2(1e-3)),   # 1ère couche : 64 neurones
        Dropout(0.5),
        Dense(32, activation = 'relu', kernel_regularizer = l2(1e-3)),   # 2ème couche : 32 neurones
        Dropout(0.5),
        Dense(16, activation = 'relu', kernel_regularizer = l2(1e-3)),   # 3ème couche : 16 neurones
        Dropout(0.5),
        Dense(8, activation = 'relu', kernel_regularizer = l2(1e-3)),    # 4ème couche : 8 neurones
        Dense(1, activation = 'sigmoid')                               # sortie : probabilité entre 0 et 1
    ], name="model_B_improved")

    model.compile(
        optimizer = Adam(learning_rate=3e-4),
        loss = 'binary_crossentropy',
        metrics = ['accuracy']
    )
    return model

model_B_improved = build_model_B_improved(input_dim)
model_B_improved.summary()
# Out:
# Model: "model_B_improved"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                     │ (None, 64)                  │           1,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 32)                  │               0 │
# ...

# %% [markdown]
# ### 10.2 Configuration de l'entraînement
#
# On adapte les hyperparamètres d'entraînement par rapport au Modèle B. Le batch size passe à 128 pour stabiliser les gradients sur notre grand dataset, et la patience monte à 20 pour laisser plus de marge au modèle avant l'arrêt automatique.

# %%
early_stop_B_improved = EarlyStopping(
    monitor = 'val_loss',           # surveille la loss sur la validation
    patience = 20,
    restore_best_weights = True     # remet les poids du meilleur epoch
)

EPOCHS_IMPROVED     = 100
BATCH_SIZE_IMPROVED = 128
THRESHOLD = 0.5

# %% [markdown]
# ### 10.3 Entraînement du Modèle B Amélioré

# %%
history_B_improved = model_B_improved.fit(
    X_train, y_train,
    validation_data = (X_val, y_val),
    epochs = EPOCHS_IMPROVED,
    batch_size = BATCH_SIZE_IMPROVED,
    callbacks = [early_stop_B_improved],
    verbose = 1
)
# Out:
# Epoch 1/100
# 2389/2389 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.6510 - loss: 0.7068 - val_accuracy: 0.7600 - val_loss: 0.5516
# Epoch 2/100
# 2389/2389 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7292 - loss: 0.5842 - val_accuracy: 0.6916 - val_loss: 0.5176
# Epoch 3/100
# 2389/2389 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7358 - loss: 0.5598 - val_accuracy: 0.6905 - val_loss: 0.5056
# Epoch 4/100
# 2389/2389 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7369 - loss: 0.5508 - val_accuracy: 0.6969 - val_loss: 0.4938
# Epoch 5/100
# 2389/2389 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7382 - loss: 0.5457 - val_accuracy: 0.6829 - val_loss: 0.4965
# Epoch 6/100
# 2389/2389 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7386 - loss: 0.5430 - val_accuracy: 0.6853 - val_loss: 0.4906
# Epoch 7/100
# 2389/2389 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7393 - loss: 0.5417 - val_accuracy: 0.6868 - val_loss: 0.4937
# Epoch 8/100
# ...

# %% [markdown]
# ### 10.4 Évaluation sur la validation

# %%
y_prob_Bi = model_B_improved.predict(X_val, verbose=0).ravel()
y_pred_Bi = (y_prob_Bi >= THRESHOLD).astype(int)

acc_Bi  = accuracy_score(y_val,  y_pred_Bi)
prec_Bi = precision_score(y_val, y_pred_Bi, zero_division=0)
rec_Bi  = recall_score(y_val,    y_pred_Bi, zero_division=0)
f1_Bi   = f1_score(y_val,        y_pred_Bi, zero_division=0)
auc_Bi  = roc_auc_score(y_val,   y_prob_Bi)

cm_Bi = confusion_matrix(y_val, y_pred_Bi)
tn_Bi, fp_Bi, fn_Bi, tp_Bi = cm_Bi.ravel()

print(f'Résultats Modèle B Amélioré : Validation (seuil = {THRESHOLD})')
print(f'  Accuracy  : {acc_Bi:.4f}')
print(f'  Precision : {prec_Bi:.4f}')
print(f'  Recall    : {rec_Bi:.4f}')
print(f'  F1-score  : {f1_Bi:.4f}')
print(f'  ROC-AUC   : {auc_Bi:.4f}')
print(f'\n  TN={tn_Bi}  FP={fp_Bi}')
print(f'  FN={fn_Bi}  TP={tp_Bi}')
print(f'\n  Résultat : {fn_Bi} diabétiques non détectés')
# Out:
# Résultats Modèle B Amélioré : Validation (seuil = 0.5)
#   Accuracy  : 0.6849
#   Precision : 0.2750
#   Recall    : 0.7708
#   F1-score  : 0.4054
#   ROC-AUC   : 0.7939
#
#   TN=21974  FP=10776
#   FN=1215  TP=4087
#
#   Résultat : 1215 diabétiques non détectés

# %%
fig, ax = plt.subplots(figsize=(6, 5))
disp = ConfusionMatrixDisplay(confusion_matrix=cm_Bi,
                              display_labels=['Non diabétique', 'Diabétique'])
disp.plot(ax=ax, cmap='Blues', values_format='d', colorbar=False)
ax.set_title(f'Matrice de confusion : Modèle B Amélioré (seuil = {THRESHOLD})')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 fig, ax = plt.subplots(figsize=(6, 5))
#       2 disp = ConfusionMatrixDisplay(confusion_matrix=cm_Bi,
#       3                               display_labels=['Non diabétique', 'Diabétique'])
#       4 disp.plot(ax=ax, cmap='Blues', values_format='d', colorbar=False)
#
# NameError: name 'plt' is not defined

# %%
plt.plot(history_B_improved.history['loss'], label='Train')
plt.plot(history_B_improved.history['val_loss'], label='Validation')
plt.title("Courbes d'apprentissage : Modèle B Amélioré")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.plot(history_B_improved.history['loss'], label='Train')
#       2 plt.plot(history_B_improved.history['val_loss'], label='Validation')
#       3 plt.title("Courbes d'apprentissage : Modèle B Amélioré")
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## 10.5 Analyse des résultats du Modèle B Amélioré
#
# Le progrès le plus visible est sur les **courbes d'apprentissage**. Sur le Modèle B, la loss de validation remontait dès l'epoch 1-2, signe clair de surapprentissage.
# Ici elle descend jusqu'à l'epoch 5 puis se stabilise. Le Dropout à 0.5 et la régularisation L2 renforcée ont donc bien joué leur rôle sur ce point.
#
# Sur les métriques, le gain est quasi nul :
# - le recall baisse légèrement (0.7765 à 0.7708)
# - le ROC-AUC progresse à peine (0.7915 à 0.7939)
# - les FN passent de 1220 à 1215, soit 5 diabétiques supplémentaires détectés
#
# Ces 1215 faux négatifs restent préoccupant. Ce sont 1215 patients diabétiques qui repartent sans diagnostic et sans prise en charge. Dans un contexte médical, même avec une réduction de 5 cas, ce chiffre reste trop élevé pour un usage médical réel.
#
# Ce résultat montre une limite importante du paramétrage manuel :
# - on justifie chaque choix mais on ne peut pas garantir que c'est la meilleure combinaison possible. En effet, par exemple, peut-être qu'un Dropout à 0.2 aurait mieux marché que 0.5. Donc on ne peut pas le savoir sans tester toutes les combinaisons.
#
# Le vrai problème est là. Même en optimisant l'architecture à la main, on reste bloqué autour du même niveau de performance.
# Ce plafond vient surtout du déséquilibre des classes (86% de non-diabétiques contre 14% de diabétiques) que le SMOTE ne corrige que partiellement, et du bruit dans les données qui sont des réponses déclaratives à une enquête téléphonique.
#
# C'est pourquoi, dans le livrable 3, nous aborderons la recherche automatisée des combinaisons d'hyperparamètres et la gestion plus poussée du déséquilibre des classes.

# %% [markdown]
# ## 13. Bibliographie
#
# - Union européenne. (2024). Règlement (UE) 2024/1689 du Parlement européen et du Conseil du 13 juin 2024 établissant des règles harmonisées concernant l'intelligence artificielle (règlement sur l'IA). Journal officiel de l'Union européenne. https://eur-lex.europa.eu/legal-content/FR/TXT/?uri=CELEX:32024R1689
#
# - Union européenne. (2016). Règlement (UE) 2016/679 du Parlement européen et du Conseil du 27 avril 2016 relatif à la protection des personnes physiques à l'égard du traitement des données à caractère personnel (RGPD), article 9. https://www.cnil.fr/fr/reglement-europeen-protection-donnees/chapitre2#Article9
#
# - Future of Life Institute. (s.d.). AI Act - Annexe III : Systèmes d'IA à haut risque. Artificial Intelligence Act. https://artificialintelligenceact.eu/fr/annex/3
